# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('mpg')

# %%
# find missing values

import matplotlib.pyplot as plt

print(df.isna().any())
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower       True
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
df.isna().sum().plot(kind='bar')
plt.show()

# %%
# Remove rows with missing values

df_complete = df.dropna()
print(df_complete.isna().any())
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
# replace missing values

cols_with_missing = ['horsepower']
df[cols_with_missing].hist()
plt.show()

# %%
# Fill in missing values with 0

df_filled = df.fillna(0)
df_filled[cols_with_missing].hist()
plt.show()
